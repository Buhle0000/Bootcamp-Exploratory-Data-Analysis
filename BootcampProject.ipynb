# %% [markdown]
# 1. Are there any missing values in the data set?
# What, if anything should be done about them if there are?

# %% [markdown]
# Yes there is missing values
# We should replace the missing values with NaN

# %% [markdown]
# 3. Identify the country with the lowest % of population Under 15 and the one with the highest

# %%
import pandas as pd

df=pd.read_csv('data.csv')


High = df['Under15'].max()
low = df['Under15'].min()


print(High)
print(low)
# Out:
# 49.99
# 13.12

# %% [markdown]
# The country most populated with Under15 is Niger with 49.99% and least populated with Under15 is Japan with 13.12%

# %% [markdown]
# 4. Which region has the highest % of population over 60?

# %%
import pandas as pd

df=pd.read_csv('data.csv')


High = df['Over60'].max()

print(High)
# Out:
# 31.92

# %% [markdown]
# The region with the highest population over 60 is Japan with 31.92%

# %% [markdown]
# 6.Which regions have the lowest literacy rates?

# %%
import pandas as pd

df=pd.read_csv('data.csv')


lowest = df['LiteracyRate'].min()

print(lowest)
# Out:
# 31.1

# %%
Most African countries have a low literacy rate, with Mali coming out lowest out of all African countries which
include the likes of Lesetho, Malawi,Liberia and so fourth

# %% [markdown]
# 7.Which regions have the lowest child mortality rates?

# %%
import pandas as pd

df=pd.read_csv('data.csv')


lowest = df['ChildMortality'].min()

print(lowest)
# Out:
# 2.2

# %% [markdown]
# Countries in Europe have the lowest Child Moertality rates with Luxembourg having the lowest rate of 2.2
# in amoungst them is Norway and Portugal and other European countries
